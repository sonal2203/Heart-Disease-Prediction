# %%
#installing req libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
#loading dataset to pandas dataframe
ds1= pd.read_csv('/content/heart_disease_data.csv')

# %%
ds1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
ds1.shape
# Out:
# (303, 14)

# %%
#checking for any missing values in dataset
ds1.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#taking another dataset to increase dataset size
ds2=pd.read_csv('/content/heart.csv')

# %%
ds2.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
ds2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
ds2.shape
# Out:
# (1025, 14)

# %%
#combining both datasets
ds_combined=pd.concat([ds1,ds2],ignore_index=True)

# %%
ds_combined.shape
# Out:
# (1328, 14)

# %%
ds_combined.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
#statistical measures about the data
ds_combined.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  1328.000000  1328.000000  1328.000000  1328.000000  1328.000000
# mean     54.418675     0.692771     0.948042   131.614458   246.060241
# std       9.071150     0.461519     1.029854    17.514997    51.627522
# min      29.000000     0.000000     0.000000    94.000000   126.000000
# 25%      48.000000     0.000000     0.000000   120.000000   211.000000
# 50%      56.000000     1.000000     1.000000   130.000000   240.000000
# 75%      61.000000     1.000000     2.000000   140.000000   275.000000
# max      77.000000     1.000000     3.000000   200.000000   564.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1328.000000  1328.000000  1328.000000  1328.000000  1328.000000
# mean      0.149096     0.529367   149.235693     0.334337     1.064232
# std       0.356318     0.527220    22.975286     0.471936     1.171519
# ...

# %%
#checking distribution of Target variable
ds_combined['target'].value_counts()
# Out:
# target
# 1    691
# 0    637
# Name: count, dtype: int64

# %%
#splitting features and target, storing features in X and target in Y
X=ds_combined.drop(columns='target', axis=1)
Y=ds_combined['target']

# %%
X
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      63    1   3       145   233    1        0      150      0      2.3
# 1      37    1   2       130   250    0        1      187      0      3.5
# 2      41    0   1       130   204    0        0      172      0      1.4
# 3      56    1   1       120   236    0        1      178      0      0.8
# 4      57    0   0       120   354    0        1      163      1      0.6
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1323   59    1   1       140   221    0        1      164      1      0.0
# 1324   60    1   0       125   258    0        0      141      1      2.8
# 1325   47    1   0       110   275    0        0      118      1      1.0
# 1326   50    0   0       110   254    0        0      159      0      0.0
# 1327   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         0   0     1
# 1         0   0     2
# ...

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1323    1
# 1324    0
# 1325    0
# 1326    1
# 1327    0
# Name: target, Length: 1328, dtype: int64

# %%
#splitting data into training and testing data
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=3)

# %%
print(X.shape,
      X_train.shape,
      X_test.shape)
# Out:
# (1328, 13) (929, 13) (399, 13)

# %% [markdown]
# Trying on various models and look for the model that gives best accuracy

# %%
'''from sklearn.metrics import accuracy_score, classification_report
models = {
    "Logistic Regression": LogisticRegression(max_iter=2000, solver='saga', random_state=42),
    "Decision Tree": DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=10, min_samples_leaf=5, random_state=42),
}'''
# Out:
# 'from sklearn.metrics import accuracy_score, classification_report\nmodels = {\n    "Logistic Regression": LogisticRegression(max_iter=2000, solver=\'saga\', random_state=42),\n    "Decision Tree": DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5, random_state=42),\n    "Random Forest": RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=10, min_samples_leaf=5, random_state=42),\n}'

# %%
'''# Initialize variables to store the model name and accuracy
best_model_name = ""
best_model = None
best_accuracy = 0

# Iterate through each model, fit and evaluate it
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, Y_train)
    # Evaluate accuracy on training data
    X_train_prediction = model.predict(X_train)
    training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

    # Evaluate accuracy on test data
    X_test_prediction = model.predict(X_test)
    test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
    print(f"{model_name} - Accuracy on Training data: {training_data_accuracy}")
    print(f"{model_name} - Accuracy on Test data: {test_data_accuracy}")

    # Checking if the current model has the highest accuracy on test data
    if test_data_accuracy > best_accuracy:
        best_accuracy = test_data_accuracy
        best_model_name = model_name
        best_model = model

# Printing the best model
print(f"\nThe model with the highest accuracy on test data is: {best_model_name}")
print(f"Test Data Accuracy of {best_model_name}: {best_accuracy}")'''
# Out:
# '# Initialize variables to store the model name and accuracy\nbest_model_name = ""\nbest_model = None\nbest_accuracy = 0\n\n# Iterate through each model, fit and evaluate it\nfor model_name, model in models.items():\n    # Train the model\n    model.fit(X_train, Y_train)\n    # Evaluate accuracy on training data\n    X_train_prediction = model.predict(X_train)\n    training_data_accuracy = accuracy_score(X_train_prediction, Y_train)\n\n    # Evaluate accuracy on test data\n    X_test_prediction = model.predict(X_test)\n    test_data_accuracy = accuracy_score(X_test_prediction, Y_test)\n    print(f"{model_name} - Accuracy on Training data: {training_data_accuracy}")\n    print(f"{model_name} - Accuracy on Test data: {test_data_accuracy}")\n\n    # Checking if the current model has the highest accuracy on test data\n    if test_data_accuracy > best_accuracy:\n        best_accuracy = test_data_accuracy\n        best_model_name = model_name\n        best_model = model\n\n# Printing the b
# ...

# %%
model=LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
'''#model evaluation
# accuracy on training data
from sklearn.metrics import accuracy_score
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)'''
# Out:
# '#model evaluation\n# accuracy on training data\nfrom sklearn.metrics import accuracy_score\nX_train_prediction = model.predict(X_train)\ntraining_data_accuracy = accuracy_score(X_train_prediction, Y_train)'

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.8503767491926802

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.8596491228070176

# %%
import pickle
with open("model.pkl", "wb") as f:
    pickle.dump(model, f)

with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# %%
from google.colab import files

files.download("model.pkl")
files.download("scaler.pkl")

# %%
input_data = (63,1,3,145,233,1,0,150,0,2.3,0,0,1)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [1]
# The Person has Heart Disease
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
